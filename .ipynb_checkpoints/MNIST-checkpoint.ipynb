# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
plt.imshow(x_train[3])
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28,28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

history = model.fit(x_train, y_train, batch_size=64, epochs=8, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/8
#  19/938 [..............................] - ETA: 5s - loss: 1.6897 - sparse_categorical_accuracy: 0.5510
# 2023-01-05 21:09:55.212826: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 938/938 [==============================] - ETA: 0s - loss: 0.3026 - sparse_categorical_accuracy: 0.9161
# 2023-01-05 21:10:00.187826: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3026 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.1643 - val_sparse_categorical_accuracy: 0.9530
# Epoch 2/8
# 938/938 [==============================] - 5s 6ms/step - loss: 0.1373 - sparse_categorical_accuracy: 0.9600 - val_loss: 0.1107 - val_sparse_categorical_accuracy: 0.9663
# Epoch 3/8
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.0933 - val_sparse_categorical_accuracy: 0.9723
# Epoch 4/8
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.0842 - val_sparse_categorical_accuracy: 0.9742
# Epoch 5/8
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0577 - sparse_categorical_accuracy: 0.9828 - val_loss: 0.0724 - val_sparse_categorical_accuracy: 0.9784
# Epoch 6/8
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9754
# Epoch 7/8
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0745 - val_sparse_categorical_accuracy: 0.9767
# Epoch 8/8
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.0719 - val_sparse_categorical_accuracy: 0.9787

# %%
import matplotlib.pyplot as plt
print(history.history.keys())
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
from PIL import Image
four = Image.open('./four.png')
four = four.resize((28, 28))
plt.imshow(four)

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_10 (Flatten)        (None, 784)               0
#
#  dense_20 (Dense)            (None, 128)               100480
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
four = np.array(four)
four = four / 255.0
four = four.reshape(1, 28, 28)

# %%
np.argmax(model.predict(four))
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 4
